# %% [markdown]
# # Check for cluster collapse
#
# Check our base clustering for pre-existing cluster collapse by comparing our clusters with those of WalletExplorer.com
#
# Note: walletexplorer.com enforces rate limits for web scraping and running the script did not work on AWS.

# %%
import blocksci

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
import collections
import random

# %%
from time import sleep

# %%
import requests

# %%
import pickle

# %%
import utils

# %%
chain = blocksci.Blockchain(utils.blocksci_config())

# %%
my_cm = blocksci.cluster.ClusterManager(utils.latest_clustering(), chain)

# %%
gt = blocksci.GroundTruth("/home/ubuntu/Data/groundtruth/20210715-2-2out-nobothclustered-nomtgox", chain)

# %%
change_output = blocksci.heuristics.change.cluster_member(my_cm)

# %%
actual_spend = blocksci.heuristics.change.actual_spend(my_cm)

# %%
cluster_id = blocksci.heuristics.cluster_id(my_cm)

# %%
address_reuse = blocksci.heuristics.change.address_reuse

# %% [markdown]
# ## Check for cluster collapse by comparing clustering against walletexplorer.com

# %%
parse_new = False

cluster_addresses = {}
cluster_labels = collections.defaultdict(dict)

if not parse_new:
    with open("cluster_addresses_2021.pickle", "rb") as f:
        cluster_addresses = pickle.load(f)
    with open("cluster_labels_2021.pickle", "rb") as f:
        cluster_labels = pickle.load(f)

# %%
if parse_new:
    change_clusters = gt.transactions().map(lambda tx: cluster_id(tx))
    change_cluster_counter = collections.Counter(change_clusters)

# %%
if parse_new:
    # add new clusters to cluster data
    random.seed(42)
    for clus_id, _ in change_cluster_counter.most_common(100):
        if clus_id not in cluster_addresses:
            cluster = my_cm.clusters()[clus_id]
            addresses = cluster.addresses.to_list()
            addresses_to_sample = min(100, len(addresses))
            cluster_addresses[clus_id] = [x.address_string for x in random.sample(addresses, addresses_to_sample)]
            print(clus_id, len(addresses))
# Out:
# 91628086 1140
# 34508 26158495
# 108873629 1197905
# 98893639 6
# 70048 2182838
# 107201 20
# 159191 2551617
# 32721661 50269
# 61817017 855717
# 23594133 2096593
# 97299909 77
# 13699970 343319
# 135574604 581328
# 105794406 314508
# 98223133 154
# 109995066 280738
# 23084303 4883462
# 20988006 623686
# 119680253 234008
# 98290865 3609
# 50075702 7
# 12503851 2758037
# 40523343 263074
# 23425421 809648
# 100336032 497982
# 96265016 259401
# 42739939 238479
# 127814957 189776
# 104400659 665
# 49550557 997254
# 99387706 350036
# 100100593 197164
# 91901708 372753
# 90536077 348445
# 103041771 505919
# 108227938 268487
# 324204316 1000
# 5282699 1239413
# 349441895 18969
# 12148954 18912
# 91784202 912682
# 188958464 170486
# 95627541 95994
# 136802 223835
# 109970812 96888
# 17786597 265686
# 102513996 1639518
# 281979729 116950
# 21928741 204948
# 21357591 133084
# 347160319 33682
# 97989378 412
# 101127446 808170
# 200307103 29
# 8093053 143556
# 17991302 301218
# 44807457 51
# 12287598 464137
# 24513187 186719
# 15449584 660
# 15025899 797581
# 24516747 183933
# 42090904 120562
# 951310 496084
# 24511841 174169
# 157111776 132541
# 107626683 134562
# 10460285 103636
# 16875573 123072
# 343937668 10
# 176532478 133386
# 107458876 85590
# 16179989 176560
# 181336 965524
# 98201535 178706
# 10996631 276020
# 285156328 45796
# 17793783 140169
# 23462341 91397
# 12200402 98381
# 19114814 128456
# 33508552 115189
# 15642255 32010
# 67049240 84174
# 127827342 41090
# 14338599 122920
# 283948717 315185
# 101600287 1018225
# 1310758 89604
# 107299715 80987
# 189114199 900804
# 142494615 523330
# 185113254 98811
# 107779541 241575
# 98124427 114458
# 28240439 190218
# 16360990 123347
# 251497680 418
# 98451464 115423
# 113172950 119119

# %% [markdown]
# ### Parse labels from Walletexplorer.com

# %%
TIMEOUT = 20

def get_cluster_from_walletexplorer(address_string):
    get_url = "https://www.walletexplorer.com/?q={}".format(address_string)
    
    try:
        r = requests.get(get_url, timeout=TIMEOUT)
    except requests.exceptions.Timeout:
        print("Request for address {} timed out".format(address_string))
        return False
    except Exception as err:
        print("Exception {} occurred for address {}".format(err, address_string))
        return False
    if r.status_code == 429:
        return False
    if r.status_code != 200:
        print("Error retrieving label for address {}: Status code {}".format(address_string, r.status_code))
        return False
    if r.url == get_url:
        print("Address {} not found".format(address_string))
        return "<Unknown>"
    
    cluster_name = r.url[38:-(14+len(address_string))]
    return cluster_name

# %%
ADDRESS_COUNT_NORMAL = 25

for cid, addresses in cluster_addresses.items():
    cl = cluster_labels[cid]
    
    for address in addresses:
        address_string = address
        
        # get 25 labels per cluster (we sampled 100 at random)
        if len(cl) >= ADDRESS_COUNT_NORMAL:
            print("Finished/skipping cluster {}".format(cid))
            break
        
        # skip addresses that we already retrieved
        if address_string in cl:
            # print("Skipping address {}: {}".format(address_string, cl[address_string]))
            continue
        
        # retrieval may fail, we try multiple times with longer wait in between
        num_tries = 0
        while True:
            # get label
            label = get_cluster_from_walletexplorer(address_string)
            if label:
                cl[address_string] = label
                print("Cluster label {} for address {} in cluster {}".format(label, address_string, cid))
                sleep(random.randint(0, 10))
                break
            else:
                if num_tries > 3:
                    print("Unable to retrieve label for address {} in cluster {}".format(address_string, cid))
                    sleep(120)
                    break
                num_tries += 1
                sleep(60*num_tries)
# Out:
# Cluster label SatoshiDice.com-original for address 1LuLbLZR1TZyk2XtQVXR888FDhdj82qAA2 in cluster 91628086
# Cluster label SatoshiDice.com-original for address 18wQeuWhrC7f96QDuyZM4VnGEDQpgmcRnH in cluster 91628086
# Cluster label SatoshiDice.com-original for address 18thk7NCdqoGqhd93PsG9hecYdSCWDiB7w in cluster 91628086
# Cluster label SatoshiDice.com-original for address 1MXZpCNEFYSX4s6stRfLagND5sdWCLJBUq in cluster 91628086
# Cluster label SatoshiDice.com-original for address 162d1ArFmninqV5gWYvCVkqTN6xtdLsxtG in cluster 91628086
# Cluster label SatoshiDice.com-original for address 1bank3Uzo8MCfhhRLSZwQnyX1Q8bkAiXg in cluster 91628086
# Cluster label SatoshiDice.com-original for address 1KDzgXk7aEv7wax94oE3FmP5tg1pDmnnDF in cluster 91628086
# Cluster label SatoshiDice.com-original for address 1Bhz89mv4MXEXFnK3uEaNfHxcr8eXu1CEj in cluster 91628086
# Cluster label SatoshiDice.com-original for address 1MQ175hiJHFN1YiXMYerWdE8pTAc5V9KZS in cluster 91628086
# Cluster label SatoshiDice.com-original for address 1C2rk9BMu9k58FHs5M4WuuhbjJqkHiJJwx in cluster 91628086
# Cluster label SatoshiDice.com-original for address 1Aqnamv1C9R9Zs2rpW1VwPVu6JHn9q5Xeh in cluster 91628086
# Cluster label SatoshiDice.com-original for address 
# Cluster label 00000014ea8b260f for address 1HnBbvq9ppj5ax46Xswdge1UeDvphRa4kW in cluster 34508
# Cluster label 00000014ea8b260f for address 39usyWad4uxj35ajfYFFvj9HbBJsaQaFUy in cluster 34508
# Cluster label 00000014ea8b260f for address bc1ql8xytxzldcdys8nxlk8c992n0dsv9pxh3t0023 in cluster 34508
# Cluster label 00000014ea8b260f for address bc1qjhxt0ugdgnq83n9ex2jr93ltsy76yt3l0fpu2v in cluster 34508
# Cluster label 00000014ea8b260f for address 1M3rNqR9iXjLZLwSsL1bswtbN3uVnU2uk8 in cluster 34508
# Cluster label 00000014ea8b260f for address 1CVH9YjWmg85aGyod4URKnoMNpc3RTdJHc in cluster 34508
# Cluster label 00000014ea8b260f for address bc1qej34tlys8fg8ny87ncp30aryn30agu7umysnry in cluster 34508
# Cluster label 00000014ea8b260f for address 35XscXc9Rav7oob4BLui7PizG2d3ad3hxx in cluster 34508
# Finished/skipping cluster 34508
# Cluster label Huobi.com-2 for address 1CVX4Ju66xZxbpqQon27c6b775V875kC2o in cluster 108873629
# Cluster label Huobi.com-2 for address 1DnoYkozn9gNZdtXvQSYqaNny66G66ULkR in cluster 108873629
# Cluster label Huobi.com-2 for address 15KRHgp1T7cpt2HUeHVGSBXLCWKumSURVT in cluster 108873629
# Cluster label Huobi.com-2 for address 16Qqtu5s5ipcD3LxRQuUa8ABstaDSTCdh5 in cluster 108873629
# Cluster label Huobi.com-2 for address 19nCnCNaKmpfVXpw4xNu6WghfhmTLHwVne in cluster 108873629
# Cluster label Huobi.com-2 for address 1Ba3cknuhmVdL7AYnXdHN9AbWAwkdPy7ra in cluster 108873629
# Cluster label Huobi.com-2 for address 1Jgk9HhigLSgRzmY8uJzLvNKKQ7TDMe5JP in cluster 108873629
# Cluster label Huobi.com-2 for address 1KT7YnqzzwAdXuKBd8stnqg9iWXycebkeu in cluster 108873629
# Cluster label 4f26173ef5c08d54 for address 1E3jmf9xRadjj5eYkq2USMN68R5D2ncJmV in cluster 108873629
# Cluster label Huobi.com-2 for address 127gttS57eiNRSZk2BsGAG3QJwCDFLi4cp in cluster 108873629
# Cluster label Huobi.com-2 for address 1LwDo5s3urueBCtLRSrMQGW5Z6tzQDmpAu in cluster 108873629
# Cluster label Huobi.com-2 for address 1E3npiGp9U3iQjejWh4S1XNJeMmdMidHhU in cluster 108873629
# Cluster label Huobi.com-2 for address 1AJDWnbfZwwoFHu6ZXKPQa2FVtwHYEuFg5 in cluster 108873629
# Cluster label Huobi.com-2 for address 1DEdy4bFenWx222QwWMH5BZBEQGHrVR333 in cluster 108873629
# Cluster label Huobi.com-2 for address 17EQLZGccJrTnzheC3dKnKcvDQwyySWiJp in cluster 108873629
# Cluster label Huobi.com-2 for address 1MJLSD11K6cN3uauHvj7z2VxTA7mN2xDBt in cluster 108873629
# Cluster label Huobi.com-2 for address 1KatJXGHqNX37Unup42JjuFNMpAcemeTjo in cluster 108873629
# Cluster label Huobi.com-2 for address 17FdUD4UCevk5cDPtWiZvfgGqch4WgutLS in cluster 108873629
# Cluster label Huobi.com-2 for address 1ArQCSNx9aPW7USLDmHXJB4UWjmJb6GAWk in cluster 108873629
# Cluster label Huobi.com-2 for address 128Vg5ZsubGW3FSfhNGfxK9Lu6QeiL69du in cluster 108873629
# Cluster label Huobi.com-2 for address 19UDxvowoTBs3efayL96Q1ZcE4LEUwwHbw in cluster 108873629
# Cluster label Huobi.com-2 for address 1FngqxrJPzzaE9hpGuUo3qh8BQd4wWvKXi in cluster 108873629
# Cluster label Huobi.com-2 for address 1izwtVCC8WREtEApLW68jzQo2jkrWfKjP in cluster 108873629
# Cluster label Huobi.com-2 for address 1Dairgt5Npx5BSHHHFqy1XCJ19z9HzmmRR in cluster 108873629
# Cluster label Huobi.com-2 for address 14UvHrEizyZrmnmkZ8pE2zDLzjupeB3epC in cluster 108873629
# Finished/skipping cluster 108873629
# Cluster label LuckyB.it for address 1LuckyR1fFHEsXYyx5QK4UFzv3PEAepPMK in cluster 98893639
# Cluster label LuckyB.it for address 1LuckyY9fRzcJre7aou7ZhWVXktxjjBb9S in cluster 98893639
# Cluster label LuckyB.it for address 1LuckyP83urTUEJE9YEaVG2ov3EDz3TgQw in cluster 98893639
# Cluster label LuckyB.it for address 1LuckyG4tMMZf64j6ea7JhCz7sDpk6vdcS in cluster 98893639
# Cluster label LuckyB.it for address 1LuckyB5VGzdZLZSBZvw8DR17iiFCpST7L in cluster 98893639
# Cluster label LuckyB.it for address 1NxaBCFQwejSZbQfWcYNwgqML5wWoE3rK4 in cluster 98893639
# Cluster label Xapo.com for address 3AcMiXkbQWmmgYnii7oKEAyqcmG5bCghrb in cluster 70048
# Cluster label Xapo.com for address 3F7spZuSV9Mmbk3yzeKgUM4p6kYNHmFsz9 in cluster 70048
# Cluster label Xapo.com for address 3EcZ7z9cF15mKZBUBP38qr5ikhdoWSoQ8N in cluster 70048
# Cluster label Xapo.com for address 354Zr7DYwqgKmz1jri6p38BWZAkWNq7rfj in cluster 70048
# Cluster label Xapo.com for address 3Dx5NUZSXVPDbUxz4GUW2jzUqwKoqr9E2W in cluster 70048
# Cluster label Xapo.com for address 34WPzuxC1K85kWg69W3Np1SWvN3wU2rdRr in cluster 70048
# Cluster label Xapo.com for address 3APNyj5igyttZmPQhMrt6nDKr1JzN5kmbB in cluster 70048
# Cluster label Xapo.com for address 3LAh3o8eB4qArPPedrKLB8c4ZtKoasLsME in cluster 70048
# Cluster label Xapo.com for address 334yEQNqiVY2pmJV13jZKKSdtz26BeDqP5 in cluster 70048
# Cluster label Xapo.com for address 3NhaLsykQksbnQxmG3Mxj1ujjsKdu3XmaV in cluster 70048
# Cluster label Xapo.com for address 39JymouVfHXJXUn3YJco17a868wd3H6nGw in cluster 70048
# Cluster label Xapo.com for address 3BtZey5zBTZnKqhbnvF6P9nvoCBmqxR64U in cluster 70048
# Cluster label Xapo.com for address 3PQkaW6ye2NRB7VeqUCvs1H9i74Q9dCtQY in cluster 70048
# Cluster label HaoBTC.com for address 1MN5NZdnMQtYbj8mBG8rQCEXrYz4vPVgdx in cluster 32721661
# Cluster label HaoBTC.com for address 3GY1ifMXQ9WPnBg3R4398kGC1GXL3hcSwT in cluster 32721661
# Cluster label HaoBTC.com for address 1FWKbQKmDFUrbyu3hoPLit8Nm4LMFdxjuq in cluster 32721661
# Cluster label HaoBTC.com for address 15LCfYctD3BAUPJQHPNQQA13m34D6T8q6K in cluster 32721661
# Cluster label HaoBTC.com for address 1LzpFV4UFPUiX7FtG9zgYyyXrkF1K8mWPH in cluster 32721661
# Cluster label HaoBTC.com for address 1Fki1rbdgpNS3mDyfWCP6sQibu1z9KfXVQ in cluster 32721661
# Cluster label HaoBTC.com for address 1GzYiFx1ru2wyRhH6RuZo1yzpFDXtr2Dhs in cluster 32721661
# Cluster label HaoBTC.com for address 1MUqwawix54pNpFvvcwGE431ZbbzyHKHiG in cluster 32721661
# Cluster label HaoBTC.com for address 1MxPiCsXPFEdqKb9o6DQmp9oBXksGrn7F6 in cluster 32721661
# Cluster label HaoBTC.com for address 3H7uQDzB7Wh6tVCVGCCq63hzSNEchMHk6R in cluster 32721661
# Cluster label HaoBTC.com for address 1LGEDx9N7v3NGEh5yadFC65N4ia3qpwQGk in cluster 32721661
# Cluster label HaoBTC.com for address 18tGoCVNoZkG9ByHRVbZdXKyZMk1CpiwgB in cluster 32721661
# Cluster label HaoBTC.com for address 1AKuhBEg1VUEgrVbvTuL6geEJvM7XcfCx1 in cluster 32721661
# Cluster label HaoBTC.com for address 1FckuqQ8YAgSaQSb9rVdRJk7gwehC75TCa in cluster 32721661
# Cluster label HaoBTC.com for address 1GBxHCpQ5wvzqtRL8PkAemWcatZjj9RypF in cluster 32721661
# Cluster label HaoBTC.com for address 14ZC6zfPQYsCji6rPTwGds4oHE2Aizdgzh in cluster 32721661
# Cluster label HaoBTC.com for address 1LKNaZL5DgbsbYHGDArmd5apSDXawHCCbh in cluster 32721661
# Cluster label HaoBTC.com for address 1HmNHxUDosu9pT55wqUg7d5nWW6nLy25mC in cluster 32721661
# Cluster label HaoBTC.com for address 36Bsf9hAbZ5RctPtzezmY25dTA4LtijHwD in cluster 32721661
# Finished/skipping cluster 32721661
# Cluster label 000004950069154a for address 1bncYafi9LTBEZdsdr7tDeLUesTNFHx6D in cluster 61817017
# Cluster label 000004950069154a for address 1KByERCE438yEZyCk8xesZ78NY1bEZfyZQ in cluster 61817017
# Cluster label 000004950069154a for address 19wmPv2jRxC8VTjpDFDGLPcRFHwxW23GUp in cluster 61817017
# Cluster label 000004950069154a for address 1HtsvG8qvWALqGdq2FzEWUnWyKNr1rXmUG in cluster 61817017
# Cluster label 000004950069154a for address 19dXknH9VEz1J1PJ6WL9LuRWX4xUj8TeTe in cluster 61817017
# Cluster label 000004950069154a for address 1NQoiBjvi1jpkxVhA14eyRTbH89WXuteHS in cluster 61817017
# Cluster label 000004950069154a for address 1Mvm9rSzDWy1LGqnqaTCRvQRegWAtWn3ZY in cluster 61817017
# Cluster label 000004950069154a for address 1FCqGd6DrTavWy5ezcf6n1H5T9k5LaQA5y in cluster 61817017
# Cluster label 000004950069154a for address 1zSqciZbZnvvAvKZB8PwZ4iMjQhoXxNx9 in cluster 61817017
# Cluster label 000004950069154a for address 3CsPmvhEk4jFX9cpoj6VzwZ57Qi2x3yeA8 in cluster 61817017
# Cluster label 000004950069154a for address 1GKKcXDw5jUmKNMCMquyvMQb7YVro1cjX6 in cluster 61817017
# Cluster label 000004950069154a for address 3QbDyWkNK75dFXw26wzFunLJjbsM5Qm3Zc in cluster 61817017
# Cluster label 000004950069154a for address 1AAQPnQr3NWzA7TJfvDoEBf4hT1UYbWvBz in cluster 61817017
# Cluster label 000004950069154a for address 1Dk7AyUcXNpgivYr9SV4iF2zpxj5CNnPB5 in cluster 61817017
# Cluster label 000004950069154a for address 3D8TR8aXbJVb5s2cNRe4GpmD8oH1zaRQTn in cluster 61817017
# Cluster label 000004950069154a for address 15UmaURAfdYK57UuZg82p7hVxFUDC1TTfw in cluster 61817017
# Cluster label 000004950069154a for address 1MyyF9QDeWth5438SEMqJE2Qc4E1pCxBzs in cluster 61817017
# Cluster label 000004950069154a for address 1Ff5J262vatVhQFeANM7aNhzkGjwWSu91B in cluster 61817017
# Cluster label 000004950069154a for address 1MN4gUGUCgaUEZNZV9DCgdpwvgT7zPqH4C in cluster 61817017
# Cluster label 000004950069154a for address 14DjVJuGRetfY6w8Qau3ETyEQY1niWVt4G in cluster 61817017
# Cluster label 000004950069154a for address 16brLM7LMiaGBLb2oVDAFfCG1ViwY44Nkx in cluster 61817017
# Cluster label 000004950069154a for address 1Ckz9zACtDCvEx5YXqmbWM9JJFgyiQpuPG in cluster 61817017
# Cluster label 000004950069154a for address 1FUx1YGMr9iB6igDbxrzJisSJKsuxfLpQq in cluster 61817017
# Cluster label 000004950069154a for address 15eVhszRhRi6D8GZmhZjXer2xeoUAhqB6P in cluster 61817017
# Cluster label 000004950069154a for address 1LFBYizERP1evSgNXfK4bbu78dr48TkFkc in cluster 61817017
# Finished/skipping cluster 61817017
# Cluster label 0000011bd9c73aab for address 18yvFc7LdxCuLfWceU8ZXjXxwtxUF2D9Zb in cluster 23594133
# Cluster label 0000011bd9c73aab for address 173ffHLxGs9L447dfHkK5doSNDrVCRyL7x in cluster 23594133
# Cluster label 0000011bd9c73aab for address 16FDy6Ku2wt81X2v3cami6o6zt1kYTybPb in cluster 23594133
# Cluster label 0000011bd9c73aab for address 1Ei9fnj2Vtnw2W4ndxTKTS4ykPHwdo3jwr in cluster 23594133
# Cluster label 0000011bd9c73aab for address 1MpHafkFeFoUcjctsav21RUuYdmtGTmZjJ in cluster 23594133
# Cluster label 0000011bd9c73aab for address 15F6d65FiXA7xg7nPJaprATdrD7hhgCgNu in cluster 23594133
# Cluster label 0000011bd9c73aab for address 1C36Nryg8vAuQXg4Bru7UpE8mS9YUhQZF5 in cluster 23594133
# Cluster label 0000011bd9c73aab for address 16TjZWoU1taK8SpaK15DgaS9zSpGqvefeA in cluster 23594133
# Cluster label 0000011bd9c73aab for address 17NPAQT1irVN3HthGQsUCBq8p4J9GgnvCp in cluster 23594133
# Cluster label 0000011bd9c73aab for address 15zNjaiqPWaZPLtbJtAiJUo5ZXLAwSHVN8 in cluster 23594133
# Cluster label 0000011bd9c73aab for address 1GMVMHMckHAQXWAfua4C9n3M4oWNNy2w2C in cluster 23594133
# Cluster label 0000011bd9c73aab for address 18PqqzqUkWrFKokMAT2rMDi9n3KNqSUAqx in cluster 23594133
# Cluster label 0000011bd9c73aab for address 1GJ25pHCQFt8tFgByjJPZ6qJfQ2VLxFZv6 in cluster 23594133
# Cluster label 0000011bd9c73aab for address 1EnF8tmsBkG8CfHdMH99PLb3bUEcGyc7JU in cluster 23594133
# Cluster label 0000011bd9c73aab for address 1EYcqqGkXJki4PXyQhCBFYNe4NyjW3EyjQ in cluster 23594133
# Cluster label 0000011bd9c73aab for address 12dCfZBV6RA3zXcgs5UymyhsFNWJWyFUoj in cluster 23594133
# Cluster label 0000011bd9c73aab for address 1MVBZfEvp5CkV8GGYZYrKikAQArvN6GX2S in cluster 23594133
# Cluster label 0000011bd9c73aab for address 3B9NpiqENi2EvaDqCDBxB7qiQNrh5apGVm in cluster 23594133
# Cluster label 0000011bd9c73aab for address 1HPqPnE6bkQCWbLn4x3p8Nmse5xsogmyfi in cluster 23594133
# Cluster label 0000011bd9c73aab for address 1LpQKZkprwvseVx3Stuud2qbjmK3KPioqW in cluster 23594133
# Cluster label 0000011bd9c73aab for address 1Kuq9s9Bp7YTU8EhtpTBRj2XmDHyoiL53t in cluster 23594133
# Cluster label 0000011bd9c73aab for address 1NnuJzuhF3Pk3LaaA7gzFjxPQ5NCuhDRSZ in cluster 23594133
# Cluster label 0000011bd9c73aab for address 1Gyes8TNHEvfWrrQKxF8x1Gs6THEmwZBi5 in cluster 23594133
# Cluster label 0000011bd9c73aab for address 1Ksz65D7dDhKV9r5yyXCd4R12EZYbkEh6Z in cluster 23594133
# Cluster label 0000011bd9c73aab for address 1PrLCLVLfd9jUVkbr8E4MuTitN5yjr8PK1 in cluster 23594133
# Finished/skipping cluster 23594133
# Cluster label BetcoinDice.tm for address 1BgZ7FDVoERkfhf6kwqmuLUC4njD6Rg3i6 in cluster 97299909
# Cluster label BetcoinDice.tm for address 1FvNAvVa962SUpxyLHbNw5xmydRdPtu2RB in cluster 97299909
# Cluster label BetcoinDice.tm for address 1Bet8kSeHDWHByQzGVoWW2ZwDVkgtWYJxZ in cluster 97299909
# Cluster label BetcoinDice.tm for address 1Bet1kBfaSrEdmrpXEDqhxYhrUpyZCK35g in cluster 97299909
# Cluster label BetcoinDice.tm for address 19eiCFoSSFqm31YUDnfd2MzofbunXxMc7Y in cluster 97299909
# Cluster label BetcoinDice.tm for address 1Bet4FNnZsv1N3XCbW6wTTyVAS9RVUePpq in cluster 97299909
# Cluster label BetcoinDice.tm for address 19oQpJQDoDF7JS99LitHEhSNjtkrMXgktf in cluster 97299909
# Cluster label BetcoinDice.tm for address 1Bet15Zqh923xeoTBctVo7MPR6bLHP2MA3 in cluster 97299909
# Cluster label BetcoinDice.tm for address 1HjPBDQXpn9vLKSxeBvWVWP8xPcSjKaoTV in cluster 97299909
# Cluster label BetcoinDice.tm for address 1MxXtdFS3NYcQXZa1iAjR5mCgy4fAVF5dw in cluster 97299909
# Cluster label BetcoinDice.tm for address 1Bet16b1xrSmqfyZA8rxbdR2iBXUtn3ai9 in cluster 97299909
# Cluster label BetcoinDice.tm for address 15b7TZTBtJbkNSA6UFBsgyo7tLCmHfCpEr in cluster 97299909
# Cluster label BetcoinDice.tm for address 1Bet5o5o23jaRB9kKNxqZ5KeBqoSm5Fh56 in cluster 97299909
# Cluster label BetcoinDice.tm for address 1Bet6okTDPYGHZ9ukKf2FFSc5EjRoFipTD in cluster 97299909
# Cluster label BetcoinDice.tm for address 14M1pmFLXw8Xq42yBdWJZAvbPnGfTKeudi in cluster 97299909
# Cluster label BetcoinDice.tm for address 1Bet12kCPomyc35y5Lt99ZNnAr2pC66dqw in cluster 97299909
# Cluster label BetcoinDice.tm for address 1H4rUozDgyLAaddBwmSeTDh6nNzkoSAQGg in cluster 97299909
# Cluster label BetcoinDice.tm for address 1
# Cluster label 00001948c1344756 for address 13SezEFfhXvPv94ZbjJzPjWUt8PDFJCBwM in cluster 109995066
# Cluster label 00001948c1344756 for address 145VVWE99sUY7C1x4963vgW2JgZHwjVxzM in cluster 109995066
# Cluster label 00001948c1344756 for address 14Y1FnhTdsuNQuTw52x561mhFNRnaQoxqt in cluster 109995066
# Cluster label 00001948c1344756 for address 1F3xmVSx8oi3aUy25dLdo5yd28gNgaZYRa in cluster 109995066
# Cluster label 00001948c1344756 for address 1AHv5mSYJKax1M1X2dnqnxE8NoU2jw9g22 in cluster 109995066
# Cluster label 00001948c1344756 for address 134qPxURfRedxpAEndQYAAdU1jUXXaWDuB in cluster 109995066
# Cluster label 00001948c1344756 for address 14UpK387hWXwJfU26aFP1z6WA47gycd1ee in cluster 109995066
# Cluster label 00001948c1344756 for address 1465a695BG35FaFef9WnppfiD99AzSQws9 in cluster 109995066
# Cluster label 00001948c1344756 for address 142y25E63hSr2P4poLZWyFQy4wCgRgwYPb in cluster 109995066
# Cluster label 00001948c1344756 for address 129Gq3qJv5V8rby4JqbgmWJ8CmYySo5yGE in cluster 109995066
# Cluster label 00001948c1344756 for address 1NDR38KyRCo8j1kN1AGH5k9a17brbLpCaL in cluster 109995066
# Cluster label 00001948c1344756 for address 18SMUmZZTk9NYaEuUaMBBXUzFfmfn7oVq5 in cluster 109995066
# Cluster label 00001948c1344756 for address 19mMihp8RijGVSRf9uMHZPvgM7NsM62kzr in cluster 109995066
# Cluster label 00001948c1344756 for address 1nAGvrUTHfTvTg5rGKmZA6kP9Qjhcuvth in cluster 109995066
# Cluster label 00001948c1344756 for address 1JCyRKw54YbH2Yewo1mPkP6553LrjC4EjV in cluster 109995066
# Cluster label 00001948c1344756 for address 1EKNxXKC8YSnbRQZ8zcaYTqXESAV6kCfwa in cluster 109995066
# Cluster label 00001948c1344756 for address 1AV2Tc9AMnSz6FdG8uzMsKwFkQWzC92e16 in cluster 109995066
# Cluster label 00001948c1344756 for address 1EzekfnKazzd8XhALbvCBsZE7R8KRSoFwH in cluster 109995066
# Cluster label 00001948c1344756 for address 1QA1K1JBMHMxk585vGjrjXjdsVtFeftKaZ in cluster 109995066
# Cluster label 00001948c1344756 for address 1BHWfU1k2cCf7FZbdGRoKs3YWnkrao7JLo in cluster 109995066
# Cluster label 00001948c1344756 for address 1Jr3T5r8LLSrDHPfLrZ3TCGwbRLSHiGHzy in cluster 109995066
# Cluster label 00001948c1344756 for address 1Dyu9wa5sAcWxe4tYmYtW9Me96VSNfAumJ in cluster 109995066
# Cluster label 00001948c1344756 for address 1Gw1BhJDDJ3KNN1DhrVz196q4PzMPPs2bx in cluster 109995066
# Cluster label 00001948c1344756 for address 16Q8ChEzyoBWHVu1sjnfgKie52HNuwqY4v in cluster 109995066
# Finished/skipping cluster 109995066
# Cluster label 00000146f9362b0e for address 39YQbzqhkpwnD9diJJQSeQoDAWqsR8ZovY in cluster 23084303
# Cluster label 00000146f9362b0e for address 3JQd6ZrYgvu93VHGvGTKcYREo7kcLt5PMr in cluster 23084303
# Cluster label 00000146f9362b0e for address 368oB3BUA62pVpVPH8wihnopmaEmxc8taL in cluster 23084303
# Cluster label 00000146f9362b0e for address 3CHVucLJe2wSmA8rgiVMNU38b58gxGRotx in cluster 23084303
# Cluster label 00000146f9362b0e for address 3P33vExJQcBxL9revtDbkaPzqRRprsebvH in cluster 23084303
# Cluster label 00000146f9362b0e for address 3GpVz5XvdYB1YVcXMSqi4rdQpGcRp5v2W1 in cluster 23084303
# Cluster label 00000146f9362b0e for address 32axVPGCKUZr5XvaN1kMMeTPheWu7sLTnu in cluster 23084303
# Cluster label 00000146f9362b0e for address 3QEAGsHKibbDUsqWthUZCEpKeSvY4PBoXG in cluster 23084303
# Cluster label 00000146f9362b0e for address 3HXWX9oZajLko9kkxbz1edMoqiZn4yiZ9J in cluster 23084303
# Cluster label 00000146f9362b0e for address 36bsc5vSyfHm79zkPrmnSbgeUrXCpphAcm in cluster 23084303
# Cluster label 00000146f9362b0e for address 3AAnQyFXex3TNNBJTJgVytbenH6MpX9F8v in cluster 23084303
# Cluster label 00000146f9362b0e for address 3HzepiRYYoAkkfLMzopybBiv8CSY2oHCs7 in cluster 23084303
# Cluster label 00000146f9362b0e for address 3A8ZTuwFMf2yiF9J1MXrUGupXnMK69iGtq in cluster 23084303
# Cluster label 00000146f9362b0e for address 3BZK2kBNsiVqd9zXjo8XfoXX8DYZ6PM7PW in cluster 23084303
# Cluster label 00000146f9362b0e for address 37v3N33mEATtEyRVbng5x9z7rLUuHTcgsz in cluster 23084303
# Cluster label 00000146f9362b0e for address 35tb3TWJsTvSPFfwAgnHuwTH5V4knpQq44 in cluster 23084303
# Cluster label 00000146f9362b0e for address 34ZhYjDRjv6eZ5Guis9W9yjeR5vqxHiW1s in cluster 23084303
# Cluster label 6996d88024a88118 for address 37CiTNr5iwnY3GEKsHWNCVbavHong9otsV in cluster 23084303
# Cluster label 00000146f9362b0e for address 34mGzG3TNBLWtU1WZg1MnkBmBE6YB7FEYk in cluster 23084303
# Cluster label 00000146f9362b0e for address 32Fr1eeR2bXXciLWfH2c3q3ZAuYuPW2S22 in cluster 23084303
# Cluster label 00000146f9362b0e for address 3JiPJcFoYJYLf6H9fcjhBQno3ArFMLoAUm in cluster 23084303
# Cluster label 00000146f9362b0e for address 38kr7EibBdWWKXfGzv7WLQviZVrJwbAXQM in cluster 23084303
# Cluster label 00000146f9362b0e for address 39my1YpokNuKBQMZq5q91TAHStLaFYTFgz in cluster 23084303
# Cluster label 00000146f9362b0e for address 3PF83GQhn4J9FtHyrWeeZ2TXPtGRztcKqu in cluster 23084303
# Cluster label 00000146f9362b0e for address 3Cvr6WB3ZfozxSJk5V5P2c6AtBKALAetdT in cluster 23084303
# Finished/skipping cluster 23084303
# Cluster label 00000e4cdafa14d4 for address 33ohFeng5Vkh2fH1cyswaKTWa6VZQ3BTGJ in cluster 20988006
# Cluster label 00000e4cdafa14d4 for address 3EShckC5RMYgs1Tvu3kLj9JEjt4hqA2nF9 in cluster 20988006
# Cluster label 00000e4cdafa14d4 for address
cluster 119680253
# Cluster label 00003e42bfac0176 for address bc1qnqzuhx4d9dyjnpnfstf0cz5fcjvgl2evzktxgd in cluster 119680253
# Cluster label 00003e42bfac0176 for address bc1qa9tqm32sh58qdve4qjr99hq75q37yu6dq9f22l in cluster 119680253
# Cluster label 00003e42bfac0176 for address bc1q2mwj7c9qs687w0nwgxugakhuct0dreenp9rsew in cluster 119680253
# Cluster label 00003e42bfac0176 for address 14gZnSxyRyDN6DRoKgTJvDnbqoCU9TpC5y in cluster 119680253
# Cluster label 00003e42bfac0176 for address bc1qeucmg7ltm2pjmwu94d2h94ayncy4f5jj0s40gk in cluster 119680253
# Cluster label 00003e42bfac0176 for address 13Z6TKTNUpBhjg1in1MCdYADJMn9a7mMnY in cluster 119680253
# Cluster label 00003e42bfac0176 for address 1LKiyY8z1MZ9ZrMLuiBnkgSXirbXYyFTkG in cluster 119680253
# Cluster label 00003e42bfac0176 for address 1Kgx1wtLhwvvw5JiVBe1bdqfVTwFJGZ9bZ in cluster 119680253
# Cluster label 00003e42bfac0176 for address bc1qy29xrcgaq3kus4xllvnxh3fwm2kpayakcp4z4n in cluster 119680253
# Cluster label 00003e42bfac0176 for address 1HxAvGXzLBAfcfm85sV4hKA2vcEwfRhbC4 in cluster 119680253
# Cluster label 00003e42bfac0176 for address 1P2QiJ73TsVDKJg5UvP6Vu1Gzk2qxy4gYA in cluster 119680253
# Cluster label 00003e42bfac0176 for address 1WCeuiA35VgJLpZQVtv7UPqSx9gayhgfv in cluster 119680253
# Cluster label 00003e42bfac0176 for address bc1q0l2upl2pn7kz6cmltz3wvq6mmlyd3484j89xkz in cluster 119680253
# Finished/skipping cluster 119680253
# Cluster label BitZillions.com for address 1bonesWAJjUhSZ2mSbUcoPXkcqyTj8WwV in cluster 98290865
# Cluster label BitZillions.com for address 1MYUoVPtPPH26gDN3ysqiS3qfvFLB9g9NF in cluster 98290865
# Cluster label BitZillions.com for address 14ZaBXfxed57crLG8myFaEbkapBP9gmrEK in cluster 98290865
# Cluster label BitZillions.com for address 1bonesJf3NR5F8AB7y1iXob7TnkjP8HKU in cluster 98290865
# Cluster label BitZillions.com for address 1CYCRrW6aEC3YmEwkSWJfmYPog2yJChLxB in cluster 98290865
# Cluster label BitZillions.com for address 1changecvXk4DnJ8r9ZKsTpyMBx6Fv8eG in cluster 98290865
# Cluster label BitZillions.com for address 1DHfDtf7dtKLTWwcsn7yLw99kpetcwi8Ji in cluster 98290865
# Cluster label BitZillions.com for address 1bonesRuyoUhAAe4a34nRXtzRy6JP3w2P in cluster 98290865
# Cluster label BitZillions.com for address 1CFhwxbx8811JBpdwsDRmDXLQjK4vfLptk in cluster 98290865
# Cluster label BitZillions.com for address 1FW488Wagx78ARekYrKfb9DMt2m247gxK4 in cluster 98290865
# Cluster label BitZillions.com for address 1bonesgdNQG9NgNjW7XWL4Pfk1KRcDbpU in cluster 98290865
# Cluster label BitZillions.com for address 19L3vXNdBisTHpVmKjiWVxcU1Z4Jv1k8Rc in cluster 98290865
# Cluster label BitZillions.com for address 1CTirwKx2Nvjor8y9ZiBFbdu58ZSC32KQX in cluster 98290865
# Cluster label BitZillions.com for address 1eSHMLX16Bto31BVWE513377s7igdYVez in cluster 98290865
# Cluster label BitZillions.com for address 1BGmMf8XtmCYB2QsHW5wrSt8vVK8Cfg8zS in cluster 98290865
# Cluster label BitZillions.com for address 1Ax8AsWVZPR4VfTtDCBW7MHvNeG47JreMw in cluster 98290865
# Cluster label BitZillions.com for address 1J7o36wjLKtMpg9NSPndRdwM8hMV3uhmmP in cluster 98290865
# Request for address 14Jp9QKUAcDcE6ajH8gn4xM3yYEAg6hLdP timed out
# Cluster label BitZillions.com for address 14Jp9QKUAcDcE6ajH8gn4xM3yYEAg6hLdP in cluster 98290865
# Cluster label BitZillions.com for address 1AuSH8tBjVxgi5BoLcQ2nzJXBzmMi3dWXF in cluster 98290865
# Cluster label BitZillions.com for address 1i2Ae6NyHrwE17svJz4SyJBUPqzF1NvyS in cluster 98290865
# Cluster label BitZillions.com for address 1B8i9ZjvF3MFsqLNXiKt2YG3vWspMziZA3 in cluster 98290865
# Cluster label BitZillions.com for address 1H829SzeFKDxyFAGGuZWKBLQxRJhpXq8ud in cluster 98290865
# Cluster label BitZillions.com for address 1FGe5LKHyzGt6hVSo5oJwdedRZFTCT51NL in cluster 98290865
# Cluster label BitZillions.com for address 1JtsQWsuphC1VDGUvUviErZF3pamQvonsF in cluster 98290865
# Cluster label BitZillions.com for address 1bonesWf7kiCiecrQstferAZVwT1hy7bq in cluster 98290865
# Finished/skipping cluster 98290865
# Request for address 3QMjVyzU2zYvGdkqHwVaCQG5PTrRPkjUPb timed out
# Cluster label 189ca06bacb6df64 for address 3QMjVyzU2zYvGdkqHwVaCQG5PTrRPkjUPb in cluster 50075702
# Cluster label 189ca06bacb6df64 for address 3AFC2ggkUNjbQ6tsvaKqPfsBo8jhysFPaE in cluster 50075702
# Cluster label 189ca06bacb6df64 for address 3Pv7L9EeYyAMcn7U3tTWyKWxFpVJHfQBTa in cluster 50075702
# Cluster label 189ca06bacb6df64 for address 3AU9DHftrh4HTVxSMbGkvJEmk7W9h7y2t2 in cluster 50075702
# Cluster label 189ca06bacb6df64 for address 32KjPxjHy3begY6E8mW8xmDUK7WmoWxpLC in cluster 50075702
# Cluster label 189ca06bacb6df64 for address 3EqEi6x3Sxw8CgmMEAG2DuoH5pwDZeiDN1 in cluster 50075702
# Cluster label 189ca06bacb6df64 for address 3DCWQ6zhqKqB51Rt6EoempwXzDV3wpTqU8 in cluster 50075702
# Cluster label CoinPayments.net for address 3EvDyRGmKjdFv31eHky4z5jPvJVWsXuML7 in cluster 12503851
# Cluster label CoinPayments.net for address 36QvTz6d5ND1j57YQCxyzKqYPcdunnez16 in cluster 12503851
# Request for address 3Gky5YjipYrtwopQHsRtVXGRVS8VfcFyHQ timed out
# ...
# Cluster label 000022408106dcc5 for address 1DD6jysEaQ4JipEDnB8H4rmjDA6yGcVf5u in cluster 107779541
# Cluster label 000022408106dcc5 for address 1CGQSwC6ZzHC9BsSBWXq5vRLYFrTpLzV1m in cluster 107779541
# Cluster label 000022408106dcc5 for address 1E4QaEUA9jVmSdtkqQzW6QZdP532GCQSrn in cluster 107779541
# Cluster label 000022408106dcc5 for address 1FQPpi9vE5gsPSwC8LvKJ9MuYhdbz6XRHg in cluster 107779541
# Cluster label 000022408106dcc5 for address 1NPByUtbkxP3u6dJjPbv4RKAJLtukkdH2L in cluster 107779541
# Cluster label 000022408106dcc5 for address 1D7k2jxq3sVkBmCYyA5eKybn4of2kxcyUV in cluster 107779541
# Cluster label 000022408106dcc5 for address 1JQVJ9xMXaQKpUBKcr5sYfLAb51pnDqJJV in cluster 107779541
# Cluster label 000022408106dcc5 for address 1JXen1ys1KGQwhrbbiJVYonqi3ynWWGQn3 in cluster 107779541
# Cluster label 000022408106dcc5 for address 1AmtNq2Cd8sXcyQecvyh6nNRY95D3g4xrP in cluster 107779541
# Cluster label 000022408106dcc5 for address 1JBKvFp2uEELwGFXUFC3NcGDSkvoLy8TLe in cluster 107779541
# Cluster label 000022408106dcc5 for address 1GrD3EJPQrpVrDDj8JjrF4d5U8yNx3fFwf in cluster 107779541
# Cluster label 000022408106dcc5 for address 1GGqhBW7GgDfTNJAKnUV19MyRVrZhPZTCV in cluster 107779541
# Finished/skipping cluster 107779541
# Cluster label Kraken.com-old for address 1NY4GU3tZvvfpUrYhNyejd4cuE4WF7uxX7 in cluster 98124427
# Cluster label Kraken.com-old for address 13qNCqXRfaayr8CPaPY8VYjWStTev7WpTf in cluster 98124427
# Cluster label Kraken.com-old for address 1DLZEdcApHM1VJ596a4YcUpQ6gjtDgQpan in cluster 98124427
# Cluster label Kraken.com-old for address 18b71RpfRhMNa84qnDXuZPVg7yWGSuX1iw in cluster 98124427
# Cluster label Kraken.com-old for address 19FwcbhsbfbzVHkSofWg3ggSFT7mKzMujb in cluster 98124427
# Cluster label Kraken.com-old for address 13fbRGcKBtDGQ8HQ2ZVJ4tqGiiHuBUGcfU in cluster 98124427
# Cluster label Kraken.com-old for address 193V1NBKoGzih9HizR8UFvu2ieL1BjBxKC in cluster 98124427
# Cluster label Kraken.com-old for address 17R1quUxRF1Cmk2Dj5mQper9QmTnZ3cHU4 in cluster 98124427
# Cluster label Kraken.com-old for address 1KHtXmcGQ3m236DRVaEGFhs3XWPubpf7iX in cluster 98124427
# Cluster label Kraken.com-old for address 1LNgaFJ8jvEmH42MuMxQnTC6DRvyxotXGt in cluster 98124427
# Cluster label Kraken.com-old for address 14NPHt658mrChCzCfJfR5d6fBfcjamDMQh in cluster 98124427
# Cluster label Kraken.com-old for address 1ZAsDz24uFHChQMuUURHFDN6YMFeXBxck in cluster 98124427
# Cluster label Kraken.com-old for address 1NKqjhgDCBSCodWsBS4oKkMzGwm3QsdMNP in cluster 98124427
# Cluster label Kraken.com-old for address 19r5Hudk59PCqfLMKqkDvp9DYj8NWGDNkH in cluster 98124427
# Cluster label Kraken.com-old for address 13WbRBGKuxKGc9yGJzHhRPqAW41kr2Yxqh in cluster 98124427
# Cluster label Kraken.com-old for address 1HWeKyU96HYwXi5bxY1Wxs4w8pFN2Eq2dR in cluster 98124427
# Cluster label Kraken.com-old for address 15AtUBj2oDkroDCKuJGp6R5bWRqqhbrvX4 in cluster 98124427
# Cluster label Kraken.com-old for address 14UqF6TF9sbCfS536sc9eGDRDSDGHz4yah in cluster 98124427
# Cluster label Kraken.com-old for address 14wdm1ozJsWDFACD5VZBA7wqE6hfPye98U in cluster 98124427
# Cluster label Kraken.com-old for address 16ETqXBsjtg2V5qp2kobCyA3piszsB32yq in cluster 98124427
# Cluster label Kraken.com-old for address 13vWVL7nuu6jQfQKRpAX21rGXwFEWE9CFg in cluster 98124427
# Cluster label Kraken.com-old for address 16ekFzscUL3Sco4WjwkZAz2iFtsocaWuC8 in cluster 98124427
# Cluster label Kraken.com-old for address 13CH93umV7nRQujnw62UWnKruYxsp2TTor in cluster 98124427
# Cluster label Kraken.com-old for address 1HTEq3sf5WriXa9utcaNZ1rqb5hcYuA7K1 in cluster 98124427
# Cluster label Kraken.com-old for address 15vpw6EtTexn2SCeGoMAjdnDZSy5u3gmzh in cluster 98124427
# Finished/skipping cluster 98124427
# Cluster label 000071b4bf4dae72 for address 39YDXcLF9P4ZnFCberEHmWF5cFseYxY3gN in cluster 28240439
# Cluster label 000071b4bf4dae72 for address bc1q4fu0rfa5rchxz9ap3wm69jhhmaaae4lfl0at24 in cluster 28240439
# Cluster label 000071b4bf4dae72 for address 39yuFcDphJnGksz9CZgpFgoVvyX2WN2D8P in cluster 28240439
# Cluster label 000071b4bf4dae72 for address 3QSDGnz3zthcZUeuVvjyfm9a1oLxvMCWYH in cluster 28240439
# Cluster label 000071b4bf4dae72 for address 3Mcx7pFR4c67Tp6b7DjyUEhGDQfoJyWTP2 in cluster 28240439
# Cluster label 000071b4bf4dae72 for address 3HrmTmVNPKzmTHE9xaWuZX6oqkJqnyVc4P in cluster 28240439
# Cluster label 000071b4bf4dae72 for address 3HWmpjM2jusoqKq33pC5nGXvuXqbHy42fx in cluster 28240439
# Cluster label 000071b4bf4dae72 for address 3JDPmkpjuMZdqM3YpTjLQTDyyKj3GaotM6 in cluster 28240439
# Cluster label 000071b4bf4dae72 for address 3GACtJKzyGRyEzXRJbvzyPpt2ubnRXfYyw in cluster 28240439
# Cluster label 000071b4bf4dae72 for address 3EcJ8kvXCoZbNRhiMNp2PqQ8wJeu6NaPWc in cluster 28240439
# Cluster label 000071b4bf4dae72 for address 3943DFbVcQa1fn4fUJwDg8jFyyn4dhDgWj in cluster 28240439
# Cluster label 000071b4bf4dae72 for address 3C1nqCTxRgoXEyCG9SVHuBZ2ZWaee4H7pF in cluster 28240439
# Cluster label 000071b4bf4dae72 for address 3FiLdE6LWj9BHE9r2LU7uE12CQYyeETy9m in cluster 28240439
# Cluster label 000071b4bf4dae72 for address 3Lm7ZCQVgUuPR21dQ2J1o1z8CcY1Qkvsui in cluster 28240439
# Cluster label 000071b4bf4dae72 for address bc1qw4cgsggl303acys4zejlnyfk5js9ushdwckcey in cluster 28240439
# Cluster label 000071b4bf4dae72 for address 3NNZ71kx6v2QF87bY3hzBo5WTbYPGq2kmo in cluster 28240439
# Cluster label 000071b4bf4dae72 for address 374UjCqtH52aHQ6x2DY5HrUzm6Zfi3u8W3 in cluster 28240439
# Cluster label 000071b4bf4dae72 for address 3NT1pY1oFt5opuyMLipBXncE25AK5Z2c24 in cluster 28240439
# Cluster label 000071b4bf4dae72 for address 32v2xHfDh5Ju2ke4nDcRHizDh2JfE6FA2Z in cluster 28240439
# Cluster label 000071b4bf4dae72 for address 3FU7D9GEKDycVY5E4Yu7pvyqQi4TKw9SrV in cluster 28240439
# Cluster label 000071b4bf4dae72 for address 34VeZKLEpAbSZFLtMBG3wWJMF5PdtX7wGt in cluster 28240439
# Cluster label 000071b4bf4dae72 for address 3DmSjSkNJ48drVTGEbZKMh1fbAk1wUVP2G in cluster 28240439
# Cluster label 000071b4bf4dae72 for address 35747SRUbUQZ2Mj8aERexvTnKZUwbvu6YA in cluster 28240439
# Cluster label 000071b4bf4dae72 for address
# Cluster label 0115607474b291b6 for address 1FNSwyMtU7cNVmMEN11CQKA4vruWYbAys3 in cluster 251497680
# Cluster label 0115607474b291b6 for address 16iSpEsdnQgDdktahCL1dMw9F15xaPm5W2 in cluster 251497680
# Cluster label 0115607474b291b6 for address 1Apzu33yrHG7zqYLgcs4qKegCpSxJip7H9 in cluster 251497680
# Cluster label 0115607474b291b6 for address 1PNe7mVzoHQWc9u2p5cWwsrV6w955YoDRz in cluster 251497680
# Cluster label 0115607474b291b6 for address 13rbZfLiBSfcbD8u5QhjDE1tj8qsfxX3m2 in cluster 251497680
# Cluster label 0115607474b291b6 for address 17q6bAmmFGqQqW864f9JVBXcUaWtXHBGkm in cluster 251497680
# Cluster label 0115607474b291b6 for address 1GhBBQJxxesGBjwbk2k3tcpWxSHzwzBZ62 in cluster 251497680
# Cluster label 0115607474b291b6 for address 15AARzFtyD5YAY2iWFigbT1WLw3V1nB6rt in cluster 251497680
# Cluster label 0115607474b291b6 for address 12XoFyupWhYGvCD7txsXWLrad8Gbs9Wgo3 in cluster 251497680
# Cluster label 0115607474b291b6 for address 126stdtArADxWdHck54meNTrdsB48Ls64m in cluster 251497680
# Cluster label 0115607474b291b6 for address 1HGdaDGTd1YpdeWdxrgaEJKvjjok8i4nHL in cluster 251497680
# Cluster label 0115607474b291b6 for address 1LiTLiuS2zU7YXiihuQA8WXWsUb7GcaWeC in cluster 251497680
# Cluster label 0115607474b291b6 for address 1UkyHR3C2CxK5EkG5E7gFW5TznABktyUC in cluster 251497680
# Cluster label 0115607474b291b6 for address 1MjRxWgmZi79cfZdpDSjBWjGFE8P2wFztk in cluster 251497680
# Cluster label 0115607474b291b6 for address 1A4rdAXSvGRyqSjJTfxUbC45AZPaMThvq in cluster 251497680
# Cluster label 0115607474b291b6 for address 1BQuPfNJoHv5KDrKBXGQ42uFZLKY6upAq9 in cluster 251497680
# Cluster label 0115607474b291b6 for address 1NMCsP72TX29wi5NcLQsZkPzjjvyNPonfz in cluster 251497680
# Finished/skipping cluster 251497680
# Cluster label CoinKite.com for address 18GQ5swCWxWf6847Hq8sJaXBChz8oARcUR in cluster 98451464
# Cluster label CoinKite.com for address 19ibkAi65xCfcMXAEqsRg2GmX7DmPHdUuT in cluster 98451464
# Cluster label CoinKite.com for address 1MGk5PS8XdmpHvmQRsHLr6F9ie7TLmrXvG in cluster 98451464
# Cluster label CoinKite.com for address 12LDGVkkabyVngmYZAzGZokptQXRUz7JM4 in cluster 98451464
# Cluster label CoinKite.com for address 12Ws9KqqHtq78UmQigXLpTvd7taMwe1dt9 in cluster 98451464
# Cluster label CoinKite.com for address 1GM5EnRVEhV2aRGFBVa2yRdU51HysXZYSm in cluster 98451464
# Cluster label CoinKite.com for address 17AdKUFPXWECvjJgzeJ7pfnvsmFYQ9NkPo in cluster 98451464
# Cluster label CoinKite.com for address 1AcYtbWKWp8TH24cMzte5oNeGj62wKXjfq in cluster 98451464
# Cluster label CoinKite.com for address 1JvGgKx4RprKvm7nDEdFw8BNj2zfkf9oCo in cluster 98451464
# Cluster label CoinKite.com for address 1L2JjjYCscJUB4Geybq3a2GtZ8ALp3YMVL in cluster 98451464
# Cluster label CoinKite.com for address 1BWpEx8ztnCXzPchgqD1AwTUmU4zQTQz37 in cluster 98451464
# Cluster label CoinKite.com for address 1JWLuSwhQcyff26phsFzD1Hef4VFwj4BS7 in cluster 98451464
# Cluster label CoinKite.com for address 1MDwi6sfoyhrgDaF2dcZz7y1zdup4U3vft in cluster 98451464
# Cluster label CoinKite.com for address 18RtFBXs69sQyrLqw4hr9DsqVN9KdFsn4r in cluster 98451464
# Cluster label CoinKite.com for address 13PXvXBW8YPvEpetX5ijkP1KunzUj3ypW7 in cluster 98451464
# Cluster label CoinKite.com for address 1PnxAz1RWDVXvwBkNtWc8pcdGXR3u2Rr5o in cluster 98451464
# Cluster label CoinKite.com for address 1CdxfNDknPn2VyVqWBsLM2nSkJ3coHJ7cc in cluster 98451464
# Cluster label CoinKite.com for address 1EVT77FvnCbX5actLSwHNfYnqv4Dr1CB9C in cluster 98451464
# Cluster label CoinKite.com for address 1BGED7EWS2bEDjJfjPRBqH7dhF9zRp6exD in cluster 98451464
# Cluster label CoinKite.com for address 1MGkWGU6hrkJQe4AjSbABE51U4XBRxvUKF in cluster 98451464
# Cluster label CoinKite.com for address 1E4ZhiantnLStDum6iU93XruZEuXYNqiGi in cluster 98451464
# Cluster label CoinKite.com for address 1GYWWbPGuYNc3yhhRLd42NL7kVbr9rbBPj in cluster 98451464
# Cluster label CoinKite.com for address 1NVsS8M6uMKBtgRejFkU7xi9KGGUnEPMP7 in cluster 98451464
# Cluster label CoinKite.com for address 16EuqhxBwZwFgoHU6rSSAsYbW2HT7SpneE in cluster 98451464
# Cluster label CoinKite.com for address 16GLSMNbnXJ7t1KxeuSTWxVNgrncfiykey in cluster 98451464
# Finished/skipping cluster 98451464
# Cluster label AbraxasMarket for address 1PXJ8UUv8cDbRXsbkMkBx1vso2W8UDionf in cluster 113172950
# Cluster label AbraxasMarket for address 1MeXGyfokLiaDAZyLXQ57gyoNiDov33u97 in cluster 113172950
# Cluster label AbraxasMarket for address 12rFWqv3k8gkQ8iSd1tkCgokV141giBRHX in cluster 113172950
# Cluster label AbraxasMarket for address 1N6Syu8w4bWb655XtGQXYkEtwroMaxu7Sb in cluster 113172950
# Cluster label AbraxasMarket for address 1Dajyt5UNDaYT1HuBVrBGPHdQ41WAoLGQ7 in cluster 113172950
# Cluster label AbraxasMarket for address 18wC7S8egYs6wQcA6yswceqbL3HRsmgSpp in cluster 113172950
# Cluster label AbraxasMarket for address 1Lize9pK1Frrc23yXeSazmJpmVZuHdkAyn in cluster 113172950
# Cluster label AbraxasMarket for address 19RkhHMzQMXnmB8qoYHcawWAkv4TNtW6hz in cluster 113172950
# Cluster label AbraxasMarket for address 1AjE1FJyBNYq2zE84v1TKVkDn4d28pKpF7 in cluster 113172950
# Cluster label AbraxasMarket for address 1HZUwTpzEd5j7t5tauNjEdfXtDjbkiC3on in cluster 113172950
# Cluster label AbraxasMarket for address 1DxwJMetPezpCv3vb7ofDKwJqexawhf85J in cluster 113172950
# Cluster label AbraxasMarket for address 14FWjQ6HAzyAGtuhVmtuvJTU4bptsrSDkQ in cluster 113172950
# Cluster label AbraxasMarket for address 19JwWtssHq49TEGmfVVWR2JavyqeBnifoe in cluster 113172950
# Cluster label AbraxasMarket for address 1GGmwSD2gtFZCTtA3hha8NxseMZ9kzLN3w in cluster 113172950
# Cluster label AbraxasMarket for address 14w8EmfpgCEqz81TYKsqgzutjqCsrRtDCX in cluster 113172950
# Cluster label AbraxasMarket for address 1PEH5fwVfCi52yFAREu69Z1Mvt17bCP88v in cluster 113172950
# Cluster label AbraxasMarket for address 1FQj2Lt3iCqEidRZzvcGXjjcLRqgrH6x6m in cluster 113172950
# Cluster label AbraxasMarket for address 12UDdmt6QeSmycKJZDMFLNjkZzJ2P1D2ns in cluster 113172950
# Cluster label AbraxasMarket for address 18KNPQYWheTMUBXbHuMEkLdjWqqkrnJqk6 in cluster 113172950
# Cluster label AbraxasMarket for address 15meULiXseh3xeCCcutZmdFvXm6P32CCX4 in cluster 113172950
# Cluster label AbraxasMarket for address 16YiD4wWiGa3vfxmE9aFBdzXoqsnL1TBWK in cluster 113172950
# Cluster label AbraxasMarket for address 1f9j25zXEUj5JtdRRVxJTPSw8XoQYaQZf in cluster 113172950
# Cluster label AbraxasMarket for address 16Pn4KGseyX3wXcEUtK7fgcteh9eN9qYQR in cluster 113172950
# Cluster label AbraxasMarket for address 1F8n6qy2hHLAuaDzpXAY2C3tXVd3pCreyr in cluster 113172950
# Cluster label AbraxasMarket for address 1yWxXDe51SRw2grpg8THz3g4yFnuqKkiM in cluster 113172950
# Finished/skipping cluster 113172950

# %%
len(cluster_labels)
# Out:
# 100

# %% [markdown]
# #### Export updated labels / addresses

# %%
import pickle

# %%
with open('cluster_labels_2021.pickle', 'wb') as f:
    pickle.dump(cluster_labels, f)

# %%
with open("cluster_addresses_2021.pickle", "wb") as f:
    pickle.dump(cluster_addresses, f)

# %% [markdown]
# ### Analyse clusters with more than one label

# %%
clusters_with_more_than_one_label = []
for k, v in cluster_labels.items():
    unique_count = len(set(v.values()))
    if unique_count > 1: # and k in hundred_most_common:
        clusters_with_more_than_one_label.append(k)
        print(k, unique_count)
        print(collections.Counter(v.values()).most_common())
        print()
# Out:
# 108873629 2
# [('Huobi.com-2', 24), ('4f26173ef5c08d54', 1)]
#
# 105794406 2
# [('00000e7f41300eb1', 24), ('9a190d275e58fe6d', 1)]
#
# 98223133 3
# [('00e32d36bec3921d', 23), ('b023bdd19c8b1b4a', 1), ('1969d67a46186f5a', 1)]
#
# 23084303 2
# [('00000146f9362b0e', 24), ('6996d88024a88118', 1)]
#
# 91784202 3
# [('LocalBitcoins.com-old', 17), ('AnxPro.com', 7), ('79ad1c33693b26a0', 1)]

# %%
clusters_with_more_than_one_label
# Out:
# [108873629, 105794406, 98223133, 23084303, 91784202]
